# %%
from openai import OpenAI
import pandas as pd
import json

# %%
import pandas as pd

data = [
  {
    "numero_radicado": 1,
    "nombre": "Juan Pérez",
    "fecha": "2024-07-22",
    "texto": "Quisiera saber los horarios de atención de la sucursal principal los días festivos.",
    "clasificacion": "Petición"
  },
  {
    "numero_radicado": 2,
    "nombre": "María Gómez",
    "fecha": "2024-07-21",
    "texto": "Solicito cambiar mi plan de telefonía móvil del plan básico al plan premium.",
    "clasificacion": "Petición"
  },
  {
    "numero_radicado": 3,
    "nombre": "Carlos Ramírez",
    "fecha": "2024-07-20",
    "texto": "El día de ayer fui atendido de manera grosera por uno de los ejecutivos de atención al cliente en la sucursal centro.",
    "clasificacion": "Queja"
  },
  {
    "numero_radicado": 4,
    "nombre": "Ana López",
    "fecha": "2024-07-19",
    "texto": "Llevé mi coche al servicio técnico y tuve que esperar más de dos horas para ser atendido, lo cual es inaceptable.",
    "clasificacion": "Queja"
  },
  {
    "numero_radicado": 5,
    "nombre": "Luis Fernández",
    "fecha": "2024-07-18",
    "texto": "Compré un televisor hace una semana y ya presenta problemas en la pantalla. Exijo un cambio de producto o reembolso.",
    "clasificacion": "Reclamo"
  },
  {
    "numero_radicado": 6,
    "nombre": "Claudia Martínez",
    "fecha": "2024-07-17",
    "texto": "Contraté un servicio de instalación de internet que debía realizarse el 15 de julio y aún no se ha llevado a cabo.",
    "clasificacion": "Reclamo"
  },
  {
    "numero_radicado": 7,
    "nombre": "Fernando Castillo",
    "fecha": "2024-07-16",
    "texto": "Sería conveniente que el sistema de reservas online permita ver la disponibilidad en tiempo real para evitar confusiones.",
    "clasificacion": "Sugerencia"
  },
  {
    "numero_radicado": 8,
    "nombre": "Isabel Rodríguez",
    "fecha": "2024-07-15",
    "texto": "Sería beneficioso que amplíen el horario de atención hasta las 8:00 PM para aquellos que trabajamos hasta tarde.",
    "clasificacion": "Sugerencia"
  },
  {
    "numero_radicado": 9,
    "nombre": "José Torres",
    "fecha": "2024-07-14",
    "texto": "Solicito información sobre los requisitos para abrir una cuenta de ahorro.",
    "clasificacion": "Petición"
  },
  {
    "numero_radicado": 10,
    "nombre": "Laura Vargas",
    "fecha": "2024-07-13",
    "texto": "El servicio de internet en mi zona ha sido muy inestable los últimos días. Necesito una solución urgente.",
    "clasificacion": "Queja"
  },
  {
    "numero_radicado": 11,
    "nombre": "Miguel Herrera",
    "fecha": "2024-07-12",
    "texto": "Solicito la cancelación de mi suscripción al servicio de streaming.",
    "clasificacion": "Petición"
  },
  {
    "numero_radicado": 12,
    "nombre": "Diana Silva",
    "fecha": "2024-07-11",
    "texto": "El producto que recibí no corresponde a lo que pedí. Necesito un reembolso.",
    "clasificacion": "Reclamo"
  },
  {
    "numero_radicado": 13,
    "nombre": "Roberto Díaz",
    "fecha": "2024-07-10",
    "texto": "La atención telefónica ha sido muy lenta y poco eficiente. Por favor, mejoren el servicio.",
    "clasificacion": "Queja"
  },
  {
    "numero_radicado": 14,
    "nombre": "Sofía Molina",
    "fecha": "2024-07-09",
    "texto": "Me gustaría sugerir la incorporación de más opciones vegetarianas en el menú del restaurante.",
    "clasificacion": "Sugerencia"
  },
  {
    "numero_radicado": 15,
    "nombre": "Ricardo López",
    "fecha": "2024-07-08",
    "texto": "Solicito el envío de la factura de mi última compra.",
    "clasificacion": "Petición"
  },
  {
    "numero_radicado": 16,
    "nombre": "Patricia Mendoza",
    "fecha": "2024-07-07",
    "texto": "La calidad del servicio de atención al cliente en línea ha sido deficiente.",
    "clasificacion": "Queja"
  },
  {
    "numero_radicado": 17,
    "nombre": "Javier Gutiérrez",
    "fecha": "2024-07-06",
    "texto": "Exijo el reembolso por el servicio de limpieza que no se realizó como se prometió.",
    "clasificacion": "Reclamo"
  },
  {
    "numero_radicado": 18,
    "nombre": "Andrea Ruiz",
    "fecha": "2024-07-05",
    "texto": "Me gustaría recibir información sobre las tarifas de los planes de seguro de salud.",
    "clasificacion": "Petición"
  },
  {
    "numero_radicado": 19,
    "nombre": "Manuel Castro",
    "fecha": "2024-07-04",
    "texto": "El cajero automático de la sucursal norte está fuera de servicio desde hace varios días.",
    "clasificacion": "Queja"
  },
  {
    "numero_radicado": 20,
    "nombre": "Marta Rivera",
    "fecha": "2024-07-03",
    "texto": "Solicito la actualización de mis datos personales en el sistema.",
    "clasificacion": "Petición"
  },
  {
    "numero_radicado": 21,
    "nombre": "Luis Jiménez",
    "fecha": "2024-07-02",
    "texto": "El producto que compré presenta defectos y no cumple con las especificaciones anunciadas.",
    "clasificacion": "Reclamo"
  },
  {
    "numero_radicado": 22,
    "nombre": "Carolina Vargas",
    "fecha": "2024-07-01",
    "texto": "El servicio de atención al cliente por chat en línea no es eficiente y tarda mucho en responder.",
    "clasificacion": "Queja"
  },
  {
    "numero_radicado": 23,
    "nombre": "José Martínez",
    "fecha": "2024-06-30",
    "texto": "Me gustaría sugerir la creación de una aplicación móvil para facilitar el acceso a los servicios.",
    "clasificacion": "Sugerencia"
  },
  {
    "numero_radicado": 24,
    "nombre": "Laura Hernández",
    "fecha": "2024-06-29",
    "texto": "Solicito información sobre los requisitos para solicitar un crédito hipotecario.",
    "clasificacion": "Petición"
  },
  {
    "numero_radicado": 25,
    "nombre": "Pedro Gómez",
    "fecha": "2024-06-28",
    "texto": "El servicio de instalación de mi nuevo equipo no se realizó en la fecha programada.",
    "clasificacion": "Reclamo"
  },
  {
    "numero_radicado": 26,
    "nombre": "Mónica Pérez",
    "fecha": "2024-06-27",
    "texto": "Solicito la reposición de mi tarjeta de crédito por pérdida.",
    "clasificacion": "Petición"
  },
  {
    "numero_radicado": 27,
    "nombre": "Juan Carlos Díaz",
    "fecha": "2024-06-26",
    "texto": "El servicio de internet ha estado fallando continuamente en las últimas semanas.",
    "clasificacion": "Queja"
  },
  {
    "numero_radicado": 28,
    "nombre": "Susana Rodríguez",
    "fecha": "2024-06-25",
    "texto": "Me gustaría sugerir la ampliación de la oferta de productos en la tienda en línea.",
    "clasificacion": "Sugerencia"
  },
  {
    "numero_radicado": 29,
    "nombre": "Carlos González",
    "fecha": "2024-06-24",
    "texto": "Solicito información sobre las promociones vigentes en productos electrónicos.",
    "clasificacion": "Petición"
  },
  {
    "numero_radicado": 30,
    "nombre": "Ana Morales",
    "fecha": "2024-06-23",
    "texto": "La atención en la sucursal sur ha sido deficiente y los tiempos de espera son excesivos.",
    "clasificacion": "Queja"
  },
  {
    "numero_radicado": 31,
    "nombre": "Miguel Álvarez",
    "fecha": "2024-06-22",
    "texto": "Solicito el cambio de producto debido a un defecto de fábrica.",
    "clasificacion": "Reclamo"
  },
  {
    "numero_radicado": 32,
    "nombre": "Lucía Torres",
    "fecha": "2024-06-21",
    "texto": "Me gustaría recibir información sobre las opciones de financiamiento disponibles.",
    "clasificacion": "Petición"
  },
  {
    "numero_radicado": 33,
    "nombre": "Gabriel Flores",
    "fecha": "2024-06-20",
    "texto": "El servicio de entrega de paquetes ha sido muy lento y no cumple con los tiempos prometidos.",
    "clasificacion": "Queja"
  },
  {
    "numero_radicado": 34,
    "nombre": "Sandra Cruz",
    "fecha": "2024-06-19",
    "texto": "Solicito el reembolso por un cargo indebido en mi factura.",
    "clasificacion": "Reclamo"
  },
  {
    "numero_radicado": 35,
    "nombre": "Diego Ramírez",
    "fecha": "2024-06-18",
    "texto": "Me gustaría sugerir la incorporación de más sucursales en la zona norte de la ciudad.",
    "clasificacion": "Sugerencia"
  },
  {
    "numero_radicado": 36,
    "nombre": "Paula Sánchez",
    "fecha": "2024-06-17",
    "texto": "Solicito el cambio de mi plan de internet a una opción con mayor velocidad.",
    "clasificacion": "Petición"
  },
  {
    "numero_radicado": 37,
    "nombre": "Marcos Castillo",
    "fecha": "2024-06-16",
    "texto": "El servicio de atención al cliente en la línea telefónica es muy ineficiente.",
    "clasificacion": "Queja"
  },
  {
    "numero_radicado": 38,
    "nombre": "Elena Díaz",
    "fecha": "2024-06-15",
    "texto": "El producto que compré llegó dañado y necesito un reemplazo o un reembolso.",
    "clasificacion": "Reclamo"
  },
  {
    "numero_radicado": 39,
    "nombre": "Álvaro Ortega",
    "fecha": "2024-06-14",
    "texto": "Solicito información sobre los programas de lealtad y beneficios para clientes frecuentes.",
    "clasificacion": "Petición"
  },
  {
    "numero_radicado": 40,
    "nombre": "Beatriz Mendoza",
    "fecha": "2024-06-13",
    "texto": "El sistema de facturación en línea presenta errores y no puedo acceder a mis facturas.",
    "clasificacion": "Queja"
  },
  {
    "numero_radicado": 41,
    "nombre": "Fernando Vargas",
    "fecha": "2024-06-12",
    "texto": "Solicito la actualización de mi dirección de envío en el sistema.",
    "clasificacion": "Petición"
  },
  {
    "numero_radicado": 42,
    "nombre": "Clara Núñez",
    "fecha": "2024-06-11",
    "texto": "El producto que adquirí no cumple con las especificaciones técnicas anunciadas.",
    "clasificacion": "Reclamo"
  },
  {
    "numero_radicado": 43,
    "nombre": "Sergio López",
    "fecha": "2024-06-10",
    "texto": "Me gustaría sugerir la implementación de un programa de puntos para clientes frecuentes.",
    "clasificacion": "Sugerencia"
  },
  {
    "numero_radicado": 44,
    "nombre": "Diana Castro",
    "fecha": "2024-06-09",
    "texto": "Solicito información sobre los seguros disponibles para proteger mis compras.",
    "clasificacion": "Petición"
  },
  {
    "numero_radicado": 45,
    "nombre": "Rodrigo Pérez",
    "fecha": "2024-06-08",
    "texto": "El servicio de entrega de mi pedido se retrasó más de una semana.",
    "clasificacion": "Queja"
  },
  {
    "numero_radicado": 46,
    "nombre": "Verónica Jiménez",
    "fecha": "2024-06-07",
    "texto": "Solicito el reembolso de un producto que no llegó en las condiciones prometidas.",
    "clasificacion": "Reclamo"
  },
  {
    "numero_radicado": 47,
    "nombre": "Mario Ruiz",
    "fecha": "2024-06-06",
    "texto": "Me gustaría sugerir la inclusión de más opciones de pago en la tienda en línea.",
    "clasificacion": "Sugerencia"
  },
  {
    "numero_radicado": 48,
    "nombre": "Alejandra Torres",
    "fecha": "2024-06-05",
    "texto": "Solicito el cambio de mi número de contacto en el sistema.",
    "clasificacion": "Petición"
  },
  {
    "numero_radicado": 49,
    "nombre": "Daniel García",
    "fecha": "2024-06-04",
    "texto": "El servicio de soporte técnico no ha sido capaz de resolver mi problema con el producto.",
    "clasificacion": "Queja"
  },
  {
    "numero_radicado": 50,
    "nombre": "Natalia Flores",
    "fecha": "2024-06-03",
    "texto": "El producto que recibí no funciona correctamente y necesito un reemplazo.",
    "clasificacion": "Reclamo"
  }
]

df = pd.DataFrame(data)

# %%
df.to_csv('../input/tabla.csv', sep=';')

# %%
openai_api_key = "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"

# %%
sys_prompt = """

    Vas a actuar como un simulador de PQRS (peticiones, quejas, reclamos y solicitudes). Para ello, necesitas ser capaz de generar datos 
    sintéticos de PQRS hipotéticas. Para ellos, cuentas con las siguientes definiciones:

    - Petición: Puede ser la solicitud de forma verbal o escrita donde se solicite a la empresa su intervención en un asunto puntual y 
    concreto. La petición puede ser que realicen una acción o simplemente solicitar cierta información.
    
    - Queja: Es la inconformidad que presenta el usuario, ya sea de manera verbal o escrita, para mostrar su disgusto hacia cierto proceso, 
    ejecutivo de atención o departamento de una empresa.
    
    - Reclamo: Es la demanda de un servicio que hace el cliente, ya sea de manera verbal o escrita de insatisfacción por el incumplimiento 
    de un derecho que no se ha respetado o se ha visto amenazado, ocasionado por la mala prestación del servicio o fallas en el producto.
    
    - Sugerencia: Cualquier expresión verbal o escrita de recomendación entregada por el cliente con el propósito de mejorar el servicio 
    y/o los productos ofrecidos.
"""

# %%
query = """
    Ayúdame generando un json con 50 entradas que contengan lo siguiente:

    - Número de radicado
    - Nombre de quién interpuso el radicado
    - Fecha de la PQRS
    - Texto de la PQRS
    - Clasificación de la PQRS

Solo devuélveme el JSON, no me entregues ningún texto ni explicación adicional.
"""

# %%
openai_client = OpenAI(base_url=None, api_key=openai_api_key)

# %%
messages = [
    {"role": "system", "content": sys_prompt},
    {"role": "user", "content": query}
]

# %%
chat_completion = openai_client.chat.completions.create(
                    messages=messages,
                    model='gpt-4o',
                    max_tokens=1000,
                    temperature=0.7,
                    response_format={"type": "json_object"})

# %%
response = chat_completion.choices[0].message.content

# %%
print(response)
# Out:
# {
#   "pqrs": [
#     {
#       "numero_radicado": "001",
#       "nombre": "Juan Pérez",
#       "fecha": "2023-01-15",
#       "texto": "Solicito información sobre los horarios de atención.",
#       "clasificacion": "Petición"
#     },
#     {
#       "numero_radicado": "002",
#       "nombre": "Ana Gómez",
#       "fecha": "2023-01-16",
#       "texto": "Estoy inconforme con el tiempo de espera en la línea de atención.",
#       "clasificacion": "Queja"
#     },
#     {
#       "numero_radicado": "003",
#       "nombre": "Carlos López",
#       "fecha": "2023-01-17",
#       "texto": "El producto que compré no funciona correctamente.",
#       "clasificacion": "Reclamo"
#     },
#     {
#       "numero_radicado": "004",
#       "nombre": "María Rodríguez",
#       "fecha": "2023-01-18",
#       "texto": "Sería útil tener una aplicación móvil para hacer seguimiento a mis pedidos.",
#       "clasificacion": "Sugerencia"
#     },
#     {
#       "numero_radicado": "005",
# ...

# %%
# Out:
# str
